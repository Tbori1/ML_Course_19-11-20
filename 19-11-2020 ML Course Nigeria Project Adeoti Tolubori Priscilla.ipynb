# %% [markdown]
# # Project
#
# In this project, our aim is to building a model for predicting wine qualities. Our label will be `quality` column. Do not forget, this is a Classification problem!
#
# ## Steps
# - Read the `winequality.csv` file and describe it.
# - Make at least 4 different analysis on Exploratory Data Analysis section.
# - Pre-process the dataset to get ready for ML application. (Check missing data and handle them, can we need to do scaling or feature extraction etc.)
# - Define appropriate evaluation metric for our case (classification).
# - Train and evaluate Decision Trees and at least 2 different appropriate algorithm which you can choose from scikit-learn library.
# - Is there any overfitting and underfitting? Interpret your results and try to overcome if there is any problem in a new section.
# - Create confusion metrics for each algorithm and display Accuracy, Recall, Precision and F1-Score values.
# - Analyse and compare results of 3 algorithms.
# - Select best performing model based on evaluation metric you chose on test dataset.
#
#
# Good luck :)

# %% [markdown]
# <h2>Adeoti Tolubori Priscilla</h2>

# %% [markdown]
# # Data

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read csv
data = pd.read_csv('winequality.csv')
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Describe our data for each feature and use .info() for get information about our dataset
# Analyse missing values

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# No missing values found and the columns in the dataset contain datatype float and interger

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Our label Distribution (countplot)
sns.countplot(data['quality'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
# Example EDA (distplot)
sns.distplot(data['citric acid'])
# Out:
# <AxesSubplot:xlabel='citric acid'>

# %%
sns.scatterplot(x=data['quality'], y = data['pH'] )
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %%
sns.pairplot(data)

# %% [markdown]
# quality_cat = []
# for i in data['quality']:
#     if i <5:
#         quality_cat.append('bad')
#     elif i >6:
#         quality_cat.append('good')
#     else:
#         quality_cat.append("Mid")
# data['quality_cat'] = quality_cat

# %%
#Lets make quality a binary target
quality_cat = []
for i in data['quality']:
    if i <=5:
        quality_cat.append('bad')
    else:
        quality_cat.append("good")
data['quality_cat'] = quality_cat

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data['residual sugar'].value_counts()
# Out:
# 2.00    156
# 2.20    131
# 1.80    129
# 2.10    128
# 1.90    117
#        ...
# 5.70      1
# 2.85      1
# 7.30      1
# 8.90      1
# 2.65      1
# Name: residual sugar, Length: 91, dtype: int64

# %%
##correlation
corrmat = data.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corrmat, annot=True,cmap=plt.cm.CMRmap_r)
plt.show()

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# pH, density, total sulfur dioxide, free sulfur dioxide, chloride and volitle acidity are negatively correlated to quality.
# Also, quality increase with respect to increase in alcohol, sulphate and citric acid

# %%
sns.scatterplot(x = data['pH'], y= data['quality'])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
sns.barplot(y = data['alcohol'], x= data['quality'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
sns.scatterplot(x = data['free sulfur dioxide'], y= data['total sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='total sulfur dioxide'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# quality_cat             1599 non-null object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 162.5+ KB

# %%
#label encoding 
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data["quality"] = label_encoder.fit_transform(data["quality"]) 
data["quality_cat"] = label_encoder.fit_transform(data["quality_cat"]) 

data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  quality_cat
# 0      9.4        2            0
# ...

# %%
df = data.copy()

# %%
# check how skewed the data is
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# quality_cat            -0.139303
# dtype: float64

# %%
df['chlorides']=np.log(data['chlorides'])
df['total sulfur dioxide']=np.log(data['total sulfur dioxide'])
df['free sulfur dioxide']=np.log(data['free sulfur dioxide'])
df['residual sugar']=np.log(data['residual sugar'])

# %%
plt.hist(df['total sulfur dioxide'])
# Out:
# (array([ 21., 124., 185., 277., 265., 320., 230., 142.,  33.,   2.]),
#  array([1.79175947, 2.17922619, 2.56669291, 2.95415963, 3.34162636,
#         3.72909308, 4.1165598 , 4.50402652, 4.89149324, 5.27895997,
#         5.66642669]),
#  <BarContainer object of 10 artists>)

# %%
#check outliers
plt.figure(figsize=(12,8))
df.boxplot(column= ['fixed acidity','volatile acidity','citric acid', 'residual sugar','chlorides','free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['pH'])
# Out:
# <AxesSubplot:xlabel='pH'>

# %%
##Treat outliers by filling it with median
from scipy import stats
import numpy as np
z=np.abs(stats.zscore(df))
print(z)
# Out:
# [[0.52835961 0.96187667 1.39147228 ... 0.96024611 0.78782264 1.07200445]
#  [0.29854743 1.96744245 1.39147228 ... 0.58477711 0.78782264 1.07200445]
#  [0.29854743 1.29706527 1.18607043 ... 0.58477711 0.78782264 1.07200445]
#  ...
#  [1.1603431  0.09955388 0.72391627 ... 0.54162988 0.45084835 0.93283195]
#  [1.39015528 0.65462046 0.77526673 ... 0.20930812 0.78782264 1.07200445]
#  [1.33270223 1.21684919 1.02199944 ... 0.54162988 0.45084835 0.93283195]]

# %%
print(np.where(z>3))
# Out:
# (array([  13,   17,   17,   19,   33,   38,   42,   43,   45,   81,   81,
#          83,   86,   88,   91,   92,   95,  106,  106,  120,  126,  127,
#         142,  144,  147,  151,  151,  151,  151,  163,  164,  169,  169,
#         181,  199,  226,  226,  240,  243,  244,  258,  258,  274,  281,
#         291,  324,  325,  339,  340,  347,  374,  381,  391,  396,  400,
#         442,  442,  451,  459,  467,  480,  480,  494,  517,  530,  535,
#         544,  554,  554,  555,  555,  557,  557,  566,  567,  568,  588,
#         595,  608,  614,  639,  649,  652,  652,  652,  666,  672,  690,
#         690,  692,  692,  695,  723,  724,  730,  754,  773,  776,  777,
#         795,  821,  832,  836,  836,  837,  837,  889,  899,  911,  917,
#         923, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1081, 1111,
#        1114, 1165, 1186, 1235, 1244, 1260, 1269, 1269, 1270, 1270, 1288,
#        1289, 1299, 1299, 1300, 1312, 1316, 1319, 1319, 1321, 1367, 1370,
# ...

# %%
dd = df[(z<3).all(axis = 1)]

# %%
dd.shape
# Out:
# (1468, 13)

# %%
dd.groupby(by="quality").count()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 1                   47                47           47              47
# 2                  632               632          632             632
# 3                  586               586          586             586
# 4                  187               187          187             187
# 5                   16                16           16              16
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density   pH  \
# quality
# 1               47                   47                    47       47   47
# 2              632                  632                   632      632  632
# 3              586                  586                   586      586  586
# 4              187                  187                   187      187  187
# 5               16                   16                    16       16   16
#
#          sulphates  alcohol  quality_cat
# quality
# ...

# %%
plt.hist(dd['total sulfur dioxide'])
# Out:
# (array([ 21.,  63., 137., 168., 245., 233., 252., 166., 126.,  57.]),
#  array([1.79175947, 2.12317807, 2.45459667, 2.78601527, 3.11743387,
#         3.44885247, 3.78027107, 4.11168967, 4.44310827, 4.77452687,
#         5.10594547]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Preprocessing
#
# - Are there any duplicated values?
# - Do we need to do feature scaling?
# - Do we need to generate new features?
# - Split Train and Test dataset. (0.7/0.3)

# %%
#dupe=dd.duplicated()
#dupe.sum()

# %% [markdown]
# There were duplicates initially but after treating the outliers the duplicates  has been removed from the dataset

# %%
##dd.drop_duplicates(keep = 'first', inplace = True)

# %%
dd['quality_cat'].count()
# Out:
# 1468

# %%
##determine the features and target variable
X = dd.drop(columns=['quality', 'quality_cat'])
y = dd['quality_cat']

# %%
X.shape
# Out:
# (1468, 11)

# %%
y.shape
# Out:
# (1468,)

# %% [markdown]
# #smoting
# import imblearn
# from imblearn.over_sampling import SMOTE
# smote = SMOTE(random_state=1)
# X_balanced, y_balanced = smote.fit_sample(X, y)
# X_balanced.shape

# %%
#split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,stratify = y, random_state=0)
y_train.value_counts()
# Out:
# 1    552
# 0    475
# Name: quality_cat, dtype: int64

# %%
#scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %% [markdown]
# import imblearn
# from imblearn.over_sampling import SMOTE
# smote = SMOTE(random_state=1)
# x_train_balanced, y_balanced = smote.fit_sample(x_train, y_train)
# x_train.shape
#
#
# from imblearn.under_sampling import RandomUnderSampler
#
# rus = RandomUnderSampler(random_state=0,replacement = True)
# rus.fit(X,y)
# X_resampled, y_resampled = rus.fit_resample(X,y)
# I

# %% [markdown]
# # ML Application
#
# - Define models.
# - Fit models.
# - Evaluate models for both train and test dataset.
# - Generate Confusion Matrix and scores of Accuracy, Recall, Precision and F1-Score.
# - Analyse occurrence of overfitting and underfitting. If there is any of them, try to overcome it within a different section.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBRFClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.metrics import recall_score, accuracy_score, precision_score, f1_score, confusion_matrix

# %%
model = LogisticRegression(solver = 'liblinear',random_state = 42)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42, solver='liblinear')

# %%
print("Accuracy of train:",model.score(X_train,y_train))
print("Accuracy of test:",model.score(X_test,y_test))
# Out:
# Accuracy of train: 0.7380720545277507
# Accuracy of test: 0.780045351473923

# %%
y_pred = model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[153,  51],
#        [ 46, 191]], dtype=int64)

# %%
print("Precision = {}".format(precision_score(y_test, y_pred)))
print("Recall = {}".format(recall_score(y_test, y_pred)))
print("Accuracy1 = {}".format(accuracy_score(y_test, y_pred)))
print("F1 Score = {}".format(f1_score(y_test, y_pred)))
# Out:
# Precision = 0.7892561983471075
# Recall = 0.8059071729957806
# Accuracy1 = 0.780045351473923
# F1 Score = 0.7974947807933194

# %%
#DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=4, random_state=42)
clf.fit(X_train,y_train)
print("Accuracy of train:",clf.score(X_train,y_train))
print("Accuracy of test:",clf.score(X_test,y_test))
# Out:
# Accuracy of train: 0.7682570593963
# Accuracy of test: 0.7210884353741497

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score, classification_report, f1_score
pred = clf.predict(X_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.67      0.69       204
#            1       0.73      0.77      0.75       237
#
#     accuracy                           0.72       441
#    macro avg       0.72      0.72      0.72       441
# weighted avg       0.72      0.72      0.72       441

# %%
print("Precision = {}".format(precision_score(y_test, pred)))
print("Recall = {}".format(recall_score(y_test, pred)))
print("Accuracy = {}".format(accuracy_score(y_test, pred)))
print("F1 Score = {}".format(f1_score(y_test, pred)))
# Out:
# Precision = 0.728
# Recall = 0.7679324894514767
# Accuracy = 0.7210884353741497
# F1 Score = 0.7474332648870636

# %%
cm = confusion_matrix(y_test, pred)
cm
# Out:
# array([[136,  68],
#        [ 55, 182]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, pred)
plt.figure(figsize=(12, 8))
ax =sns.heatmap(cm, square=True, annot=True, cbar=False)
plt.show()

# %%
#RandomForestClassifier
Rlf = RandomForestClassifier(n_estimators = 50, max_depth=4, random_state=42)
Rlf.fit(X_train,y_train)
print("Accuracy of train:",Rlf.score(X_train,y_train))
print("Accuracy of test:",Rlf.score(X_test,y_test))
# Out:
# Accuracy of train: 0.7916260954235638
# Accuracy of test: 0.7936507936507936

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score, classification_report, f1_score
Rlf_pred = Rlf.predict(X_test)
print(classification_report(y_test,Rlf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.78       204
#            1       0.80      0.81      0.81       237
#
#     accuracy                           0.79       441
#    macro avg       0.79      0.79      0.79       441
# weighted avg       0.79      0.79      0.79       441

# %%
print("Precision = {}".format(precision_score(y_test, Rlf_pred)))
print("Recall = {}".format(recall_score(y_test, Rlf_pred)))
print("Accuracy = {}".format(accuracy_score(y_test, Rlf_pred)))
print("F1 Score = {}".format(f1_score(y_test, Rlf_pred)))
# Out:
# Precision = 0.8041666666666667
# Recall = 0.8143459915611815
# Accuracy = 0.7936507936507936
# F1 Score = 0.8092243186582809

# %%
cm = confusion_matrix(y_test, Rlf_pred)
cm
# Out:
# array([[157,  47],
#        [ 44, 193]], dtype=int64)

# %%
#Feature Importance
plt.figure(figsize=(12, 8))
importance = Rlf.feature_importances_
sns.barplot(x=importance, y=X.columns)
plt.show()

# %%
importance
# Out:
# array([0.03027465, 0.0904303 , 0.03750498, 0.02132473, 0.0372429 ,
#        0.0192673 , 0.12260172, 0.0812162 , 0.0276456 , 0.21899364,
#        0.31349797])

# %% [markdown]
# from feature importance, alcohol, sulphate,total sulphur dioxide and volatile acidity and density seem to have the most importance.

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train,y_train)
pred_svc =svc.predict(X_test)

# %%
print(classification_report(y_test,pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.78      0.76       204
#            1       0.80      0.75      0.78       237
#
#     accuracy                           0.77       441
#    macro avg       0.77      0.77      0.77       441
# weighted avg       0.77      0.77      0.77       441

# %%
cm = confusion_matrix(y_test, pred_svc)
cm
# Out:
# array([[160,  44],
#        [ 59, 178]], dtype=int64)

# %%
# XGBRFClassifier model
extreme = XGBRFClassifier()
extreme.fit(X_train, y_train)
extreme_pred = extreme.predict(X_test)

# %%
print("Accuracy of train:",extreme.score(X_train,y_train))
print("Accuracy of test:",extreme.score(X_test,y_test))
# Out:
# Accuracy of train: 0.8607594936708861
# Accuracy of test: 0.7936507936507936

# %%
print("Precision = {}".format(precision_score(y_test, extreme_pred, average='macro')))
print("Recall = {}".format(recall_score(y_test, extreme_pred, average='macro')))
print("Accuracy = {}".format(accuracy_score(y_test, extreme_pred)))
print("F1 Score = {}".format(f1_score(y_test, extreme_pred,average='macro')))
# Out:
# Precision = 0.7935504763496574
# Recall = 0.7906118143459915
# Accuracy = 0.7936507936507936
# F1 Score = 0.7915759952218961

# %%
cm = confusion_matrix(y_test, extreme_pred)
cm
# Out:
# array([[153,  51],
#        [ 40, 197]], dtype=int64)

# %%
#KNN model
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
knn_pred=knn.predict(X_test)
print(classification_report(y_test, knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.67      0.70       204
#            1       0.74      0.80      0.77       237
#
#     accuracy                           0.74       441
#    macro avg       0.74      0.73      0.74       441
# weighted avg       0.74      0.74      0.74       441

# %%
print("Accuracy of train:", knn.score(X_train,y_train))
print("Accuracy of test:", knn.score(X_test,y_test))
# Out:
# Accuracy of train: 0.8257059396299903
# Accuracy of test: 0.7392290249433107

# %%
print("Precision = {}".format(precision_score(y_test, knn_pred)))
print("Recall = {}".format(recall_score(y_test, knn_pred)))
print("Accuracy = {}".format(accuracy_score(y_test, knn_pred)))
print("F1 Score = {}".format(f1_score(y_test, knn_pred)))
# Out:
# Precision = 0.73828125
# Recall = 0.7974683544303798
# Accuracy = 0.7392290249433107
# F1 Score = 0.766734279918864

# %%
cm = confusion_matrix(y_test, knn_pred)
cm
# Out:
# array([[137,  67],
#        [ 48, 189]], dtype=int64)

# %%
#for xgboost using gradient boosting
XGB = XGBClassifier()
XGB.fit(X_train, y_train)
XGB_pred = XGB.predict(X_test)

# %%
print("Accuracy of train:", XGB.score(X_train,y_train))
print("Accuracy of test:", XGB.score(X_test,y_test))
# Out:
# Accuracy of train: 1.0
# Accuracy of test: 0.8231292517006803

# %%
print("Precision = {}".format(precision_score(y_test, XGB_pred)))
print("Recall = {}".format(recall_score(y_test, XGB_pred)))
print("Accuracy = {}".format(accuracy_score(y_test, XGB_pred)))
print("F1 Score = {}".format(f1_score(y_test, XGB_pred)))
# Out:
# Precision = 0.8271604938271605
# Recall = 0.8481012658227848
# Accuracy = 0.8231292517006803
# F1 Score = 0.8374999999999999

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score, classification_report, f1_score
XGB_pred = XGB.predict(X_test)
print(classification_report(y_test,XGB_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81       204
#            1       0.83      0.85      0.84       237
#
#     accuracy                           0.82       441
#    macro avg       0.82      0.82      0.82       441
# weighted avg       0.82      0.82      0.82       441

# %%
cm = confusion_matrix(y_test, XGB_pred)
cm
# Out:
# array([[162,  42],
#        [ 36, 201]], dtype=int64)

# %% [markdown]
# # Evaluation
# Select the best performing model and write your comments about why choose this model.
# Analyse results and make comment about how you can improve model.

# %%
#Result of the model in tabular 

conclusion = pd.DataFrame({'models': ["Logistic Regression","Decision Tree","SVC","Random Forest","KNN","Gradient boosting",],
'accuracies': [accuracy_score(y_test, y_pred), accuracy_score(y_test, pred), accuracy_score(y_test,pred_svc),accuracy_score(y_test,Rlf_pred),accuracy_score(y_test,knn_pred), accuracy_score(y_test, XGB_pred)]})

conclusion
# Out:
#                 models  accuracies
# 0  Logistic Regression    0.780045
# 1        Decision Tree    0.721088
# 2                  SVC    0.766440
# 3        Random Forest    0.793651
# 4                  KNN    0.739229
# 5    Gradient boosting    0.823129

# %% [markdown]
# Gradient boosting is the best performing model followed by random forest.
# Boosting consider homogenous weak learners, Gradient boost predict on dataset,
# gets the errors and make predictions on the errors, hence its advantage over other models used in this project.

# %%
# Predicting on dataset without removing outliers

# %%
##determine the features and target variable
X = df.drop(columns=['quality', 'quality_cat'])
y = df['quality_cat']

# %%
#split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size=0.3,stratify = y, random_state=0)
y_train1.value_counts()
# Out:
# 1    598
# 0    521
# Name: quality_cat, dtype: int64

# %%
#scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train1_scaled = sc.fit_transform(X_train1)
X_test1_scaled = sc.transform(X_test1)

# %%
#RandomForestClassifier
Rlf = RandomForestClassifier(n_estimators = 50, max_depth=4, random_state=42)
Rlf.fit(X_train1,y_train1)
print("Accuracy of train:",Rlf.score(X_train1,y_train1))
print("Accuracy of test:",Rlf.score(X_test1,y_test1))
# Out:
# Accuracy of train: 0.7899910634495085
# Accuracy of test: 0.7625

# %%
#The model is obviously not doing well on the test dataset but it is ok on train dataset without removing outliers.

# %% [markdown]
# Recommendations:
#
# Hyperparameter tuning could be done to improve the models
#
# Feature selection and cross validation could help the model learn better thereby, improving the model performance.
